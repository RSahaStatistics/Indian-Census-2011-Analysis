# %% [markdown]
# # A Data Analysis Project On 'India Census 2011 Dataset'
# by- Rajesh Saha

# %% [markdown]
# # Description:
# Here I analyze the Indian census data. This data is about the state, districts, populaton, demography, literacy, workers, religion education,age

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# Out:
# C:\Users\com\AppData\Roaming\Python\Python310\site-packages\scipy\__init__.py:169: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data=pd.read_csv(r"C:\Users\com\Downloads\6. India Census 2011.csv")

# %%
data.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
data
# Out:
#      District_code                   State_name              District_name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# ...

# %% [markdown]
# # Checking Missing and Duplicate values

# %%
data.isnull().sum()
# Out:
# District_code           0
# State_name              0
# District_name           0
# Population              0
# Male                    0
# Female                  0
# Literate                0
# Workers                 0
# Male_Workers            0
# Female_Workers          0
# Cultivator_Workers      0
# Agricultural_Workers    0
# Household_Workers       0
# Hindus                  0
# Muslims                 0
# Christians              0
# Sikhs                   0
# Buddhists               0
# Jains                   0
# Secondary_Education     0
# Higher_Education        0
# Graduate_Education      0
# Age_Group_0_29          0
# Age_Group_30_49         0
# Age_Group_50            0
# dtype: int64

# %% [markdown]
# Note: There is no missing values

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [District_code, State_name, District_name, Population, Male, Female, Literate, Workers, Male_Workers, Female_Workers, Cultivator_Workers, Agricultural_Workers, Household_Workers, Hindus, Muslims, Christians, Sikhs, Buddhists, Jains, Secondary_Education, Higher_Education, Graduate_Education, Age_Group_0_29, Age_Group_30_49, Age_Group_50]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# Note: There is no duplicates values

# %% [markdown]
# # Now we show some selected datas
# like- New Delhi, Kolkata, Nadia, chennai

# %%
data[data['District_name'].isin(['New Delhi', 'Kolkata', 'Nadia', 'chennai'])]
# Out:
#      District_code    State_name District_name  Population     Male   Female  \
# 93              94  NCT OF DELHI     New Delhi      142004    77942    64062
# 335            336   WEST BENGAL         Nadia     5167600  2653768  2513832
# 341            342   WEST BENGAL       Kolkata     4496694  2356766  2139928
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93     114179    59541         46940           12601  ...        4852   2933
# 335   3480555  1842607       1554090          288517  ...       33835    849
# 341   3588137  1795740       1412466          383274  ...       39758  13849
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93         312    679                15942             17742
# 335        514    281               412193            236828
# 341       4771  21178               555529            425245
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# # Calculate state-wise:

# %% [markdown]
# How to delete columns from data

# %%
df = data.drop(['District_code','State_name','District_name'],axis=1)
df
# Out:
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# 0        870354  474190  396164    439654   229064        190899
# 1        753745  398041  355704    335649   214866        162578
# 2        133487   78971   54516     93770    75079         53265
# 3        140802   77785   63017     86236    51873         39839
# 4        476835  251899  224936    261724   161393        117677
# ..          ...     ...     ...       ...      ...           ...
# 635       41816   19143   22673     36470    11802          9093
# 636      200222   97809  102413    154916    68301         53139
# 637       36842   20727   16115     25332    17125         12714
# 638      105597   54861   50736     78683    38579         30612
# 639      238142  127283  110859    190266    96831         77563
#
#      Female_Workers  Cultivator_Workers  Agricultural_Workers  \
# 0             38165               34680                 56759
# ...

# %% [markdown]
# Describe the data

# %%
df.describe()
# Out:
#          Population          Male        Female      Literate       Workers  \
# count  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean   1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06  7.529514e+05
# std    1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06  6.071622e+05
# min    8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03  3.555000e+03
# 25%    8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05  3.284688e+05
# 50%    1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05  6.223410e+05
# 75%    2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06  1.036544e+06
# max    1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06  4.492767e+06
#
#        Male_Workers  Female_Workers  Cultivator_Workers  Agricultural_Workers  \
# count  6.400000e+02    6.400000e+02        6.400000e+02          6.400000e+02
# mean   5.186561e+05    2.342953e+05        1.856387e+05          2.255513e+05
# ...

# %% [markdown]
# Total population

# %%
data_with_Total_population=data.groupby('State_name').Population.sum().sum()
data_with_Total_population
# Out:
# 1210854977

# %% [markdown]
# Total population statewise

# %%
data_with_population=data.groupby('State_name').Population.sum().sort_values(ascending = False)
data_with_population
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %% [markdown]
# Statewise number of workers

# %%
data_with_workers=data.groupby('State_name').Workers.sum().sort_values(ascending = False)
data_with_workers
# Out:
# State_name
# UTTAR PRADESH                  65814715
# MAHARASHTRA                    49427878
# ANDHRA PRADESH                 39422906
# WEST BENGAL                    34756355
# BIHAR                          34724987
# TAMIL NADU                     32884681
# MADHYA PRADESH                 31574133
# RAJASTHAN                      29886255
# KARNATAKA                      27872597
# GUJARAT                        24767747
# ORISSA                         17541589
# JHARKHAND                      13098274
# CHHATTISGARH                   12180225
# ASSAM                          11969690
# KERALA                         11619063
# PUNJAB                          9897362
# HARYANA                         8916508
# NCT OF DELHI                    5587049
# JAMMU AND KASHMIR               4322713
# UTTARAKHAND                     3872275
# HIMACHAL PRADESH                3559422
# TRIPURA                         1469521
# MANIPUR                         1304610
# ...

# %% [markdown]
# Religious demography

# %%
data_religious = data.groupby('State_name')['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains'].sum().sort_values(by='Hindus')
data_religious
# Out:
# C:\Users\com\AppData\Local\Temp\ipykernel_6580\325052913.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data_religious = data.groupby('State_name')['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains'].sum().sort_values(by='Hindus')
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# LAKSHADWEEP                       1788     62268         317         8
# MIZORAM                          30136     14832      956331       286
# NAGALAND                        173054     48963     1739651      1890
# DAMAN AND DIU                   220150     19277        2820       172
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286
# DADRA AND NAGAR HAVELI          322857     12922        5113       217
# MEGHALAYA                       342078    130399     2213027      3045
# ...

# %% [markdown]
# Educational demography

# %%
data_education = data.groupby('State_name')['Secondary_Education','Higher_Education','Graduate_Education'].sum().sort_values(by='Secondary_Education')
data_education
# Out:
# C:\Users\com\AppData\Local\Temp\ipykernel_6580\3831809981.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data_education = data.groupby('State_name')['Secondary_Education','Higher_Education','Graduate_Education'].sum().sort_values(by='Secondary_Education')
#                              Secondary_Education  Higher_Education  \
# State_name
# LAKSHADWEEP                                13997              6642
# DAMAN AND DIU                              36042             18537
# DADRA AND NAGAR HAVELI                     37809             22700
# SIKKIM                                     54858             34950
# ANDAMAN AND NICOBAR ISLANDS                61182             43620
# CHANDIGARH                                124707             98786
# ARUNACHAL PRADESH                         124932             90576
# MIZORAM                                   162403             68119
# ...

# %% [markdown]
# Note: Also there is some interesting data in states and also between the Secondary_Education, Higher_Education, Graduate_Education numbers

# %% [markdown]
# Calculate statewise literacy

# %%
data_with_Literate=data.groupby('State_name').Literate.sum().sort_values(ascending = False)
data_with_Literate
# Out:
# State_name
# UTTAR PRADESH                  114397555
# MAHARASHTRA                     81554290
# WEST BENGAL                     61538281
# BIHAR                           52504553
# TAMIL NADU                      51837507
# ANDHRA PRADESH                  50556760
# MADHYA PRADESH                  42851169
# GUJARAT                         41093358
# KARNATAKA                       40647322
# RAJASTHAN                       38275282
# KERALA                          28135824
# ORISSA                          26742595
# ASSAM                           19177977
# PUNJAB                          18707137
# JHARKHAND                       18328069
# HARYANA                         16598988
# CHHATTISGARH                    15379922
# NCT OF DELHI                    12737767
# JAMMU AND KASHMIR                7067233
# UTTARAKHAND                      6880953
# HIMACHAL PRADESH                 5039736
# TRIPURA                          2804783
# ...

# %% [markdown]
# Calculate statewise literacy rate

# %%
data_with_Literate_percentage=data.groupby('State_name').Literate.sum()*100/data_with_population.sort_values(ascending = False)
data_with_Literate_percentage
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS    77.324144
# ANDHRA PRADESH                 59.773345
# ARUNACHAL PRADESH              55.358102
# ASSAM                          61.456892
# BIHAR                          50.436916
# CHANDIGARH                     76.312284
# CHHATTISGARH                   60.206705
# DADRA AND NAGAR HAVELI         64.947383
# DAMAN AND DIU                  77.454604
# GOA                            79.907511
# GUJARAT                        67.990681
# HARYANA                        65.475466
# HIMACHAL PRADESH               73.416288
# JAMMU AND KASHMIR              56.351669
# JHARKHAND                      55.559581
# KARNATAKA                      66.531016
# KERALA                         84.223710
# LAKSHADWEEP                    81.511641
# MADHYA PRADESH                 59.001861
# MAHARASHTRA                    72.573770
# MANIPUR                        66.828210
# MEGHALAYA                      60.164199
# ...

# %% [markdown]
# # Particularly For West Bengal

# %% [markdown]
# Access all data of West Bengal

# %%
West_Bengal_Data = data[data.State_name == 'WEST BENGAL']
West_Bengal_Data
# Out:
#      District_code   State_name               District_name  Population  \
# 326            327  WEST BENGAL                   Darjiling     1846823
# 327            328  WEST BENGAL                  Jalpaiguri     3872846
# 328            329  WEST BENGAL                  Koch Bihar     2819086
# 329            330  WEST BENGAL              Uttar Dinajpur     3007134
# 330            331  WEST BENGAL            Dakshin Dinajpur     1676276
# 331            332  WEST BENGAL                      Maldah     3988845
# 332            333  WEST BENGAL                 Murshidabad     7103807
# 333            334  WEST BENGAL                     Birbhum     3502404
# 334            335  WEST BENGAL                  Barddhaman     7717563
# 335            336  WEST BENGAL                       Nadia     5167600
# 336            337  WEST BENGAL  North Twenty Four Parganas    10009781
# 337            338  WEST BENGAL                       Hugli     5519145
# ...

# %% [markdown]
# District wise population distribution

# %%
data_with_population_West_Bengal = West_Bengal_Data.groupby('District_name').Population.sum().sort_values(ascending = False)
data_with_population_West_Bengal
# Out:
# District_name
# North Twenty Four Parganas    10009781
# South Twenty Four Parganas     8161961
# Barddhaman                     7717563
# Murshidabad                    7103807
# Paschim Medinipur              5913457
# Hugli                          5519145
# Nadia                          5167600
# Purba Medinipur                5095875
# Haora                          4850029
# Kolkata                        4496694
# Maldah                         3988845
# Jalpaiguri                     3872846
# Bankura                        3596674
# Birbhum                        3502404
# Uttar Dinajpur                 3007134
# Puruliya                       2930115
# Koch Bihar                     2819086
# Darjiling                      1846823
# Dakshin Dinajpur               1676276
# Name: Population, dtype: int64

# %% [markdown]
# Total Number of Male Workers

# %%
data[data.State_name == 'WEST BENGAL']['Male_Workers'].sum()
# Out:
# 26716047

# %% [markdown]
# West Bengal religious data

# %%
West_Bengal_religious_data = West_Bengal_Data.groupby('District_name')['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains'].sum().sort_values(by='Hindus')
West_Bengal_religious_data
# Out:
# C:\Users\com\AppData\Local\Temp\ipykernel_6580\1530955965.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   West_Bengal_religious_data = West_Bengal_Data.groupby('District_name')['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains'].sum().sort_values(by='Hindus')
#                              Hindus  Muslims  Christians  Sikhs  Buddhists  \
# District_name
# Dakshin Dinajpur            1232850   412788       24794    276        148
# Darjiling                   1366681   105086      141848   2032     209240
# Uttar Dinajpur              1482943  1501170       16702    477        432
# Maldah                      1914352  2045151       13209    747        359
# Koch Bihar                  2087766   720033        4122    449        445
# Birbhum                     2181515  1298054       10906    582        258
# Murshidabad                 2359061  4707573       18102    766        348
# ...

# %% [markdown]
# West Bengal education data

# %%
West_Bengal_education = West_Bengal_Data.groupby('District_name')['Secondary_Education','Higher_Education','Graduate_Education'].sum().sort_values(by='Secondary_Education')
West_Bengal_education
# Out:
# C:\Users\com\AppData\Local\Temp\ipykernel_6580\84168250.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   West_Bengal_education = West_Bengal_Data.groupby('District_name')['Secondary_Education','Higher_Education','Graduate_Education'].sum().sort_values(by='Secondary_Education')
#                             Secondary_Education  Higher_Education  \
# District_name
# Dakshin Dinajpur                         135556             63286
# Uttar Dinajpur                           163106             73395
# Darjiling                                176129            113905
# Puruliya                                 177459             91807
# Koch Bihar                               209153             93119
# Maldah                                   238078            109719
# Birbhum                                  245201            122865
# Bankura                                  261478            143882
# ...

# %% [markdown]
# # Data Visualization

# %%
data_with_population.plot(kind='bar')
plt.title('Population in states')
# Out:
# Text(0.5, 1.0, 'Population in states')

# %%
data_with_workers.plot(kind='bar')
plt.title('Number of workers in states')
# Out:
# Text(0.5, 1.0, 'Number of workers in states')

# %% [markdown]
# Note: Uttar Pradesh population wish number one and also by number of workers similarly for Maharashtra but there is some noteable difference for the case of Bihar,West Bengal,Andhra Pradesh,Madhya Pradesh and Tamil Nadu.

# %%
data_with_Literate.plot(kind='pie')
plt.title('Literate population in india')
plt.figure(figsize=(10,20))

# %%
data_religious.plot(kind='bar')
plt.title('Religious demography in india')
# Out:
# Text(0.5, 1.0, 'Religious demography in india')

# %%
data_education.plot(kind='bar')
plt.title('Literate population in india')
# Out:
# Text(0.5, 1.0, 'Literate population in india')

# %%
data_with_population_West_Bengal.plot(kind='bar')
plt.title('Population in West Bengal over District')
# Out:
# Text(0.5, 1.0, 'Population in West Bengal over District')

# %%
West_Bengal_religious_data.plot(kind='bar')
plt.title('Religious demography in West Bengal Over district')
# Out:
# Text(0.5, 1.0, 'Religious demography in West Bengal Over district')

# %%
West_Bengal_education.plot(kind='bar')
plt.title('Literate population in West Bengal')
# Out:
# Text(0.5, 1.0, 'Literate population in West Bengal')
